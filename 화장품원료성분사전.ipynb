# %%
import pandas as pd

df_old = pd.read_excel('C:/Users/DFINE13/OneDrive/바탕 화면/티온전체파일/티온-작업/화장품원료성분목록(2021.01.29).xlsx')
df_new = pd.read_excel('C:/Users/DFINE13/OneDrive/바탕 화면/티온전체파일/티온-작업/화장품원료성분목록(2021.07.01).xlsx')

# %%
df_old['ver'] = 'old'
df_new['ver'] = 'new'

# %%
id_dropped = set(df_old['표준명']) - set(df_new['표준명'])
id_added = set(df_new['표준명']) - set(df_old['표준명'])

print('삭제된 아이템: ',id_dropped)
print('\n\n추가된 아이템: ',id_added)
# Out:
# 삭제된 아이템:  {'부테아 수퍼바추출물', '클레마티스알피나캘러스추출물', '알라닌글구타메이트', '메틸메타크릴레이트', '페이퍼플라워잎세포추출물', '모로코캐모마일꽃오일', '소듐솝베이스', '락토바실러스/배초향/구릿대뿌리/참당귀뿌리/쑥잎/감국/약모밀/당개나리열매/감초뿌리/지치뿌리/인동덩굴꽃/작약뿌리/도라지뿌리/탱자열매/삼백초/황금뿌리/고삼뿌리/개구리밥/민들레/도꼬마리열매발효여과물', '서양뒤영벌글라이코스아미노글리칸', '철피석곡캘러스추출물', '벤질파라벤', '네덜란드라벤더오일', '창포뿌리/줄기/수세미오이/차나무잎추출물', '하이드롤라이즈드체리모야추출물', '사이클로헥실아민', '코네씨씨추출물', '토마토줄기세포', '마스티키나백리향꽃오일', '수어숍잎/줄기추출물', '큰열매모자반잎/줄기추출물', '탐보우리사 트리코퓔라나무잎추출물', '큰땅빈대잎/줄기추출물', '아틀란티카개잎갈나무껍질수', '루테아용담뿌리줄기/뿌리추출물', '치자청색소', '붉은가시나무가지/잎추출물', '키투르스 타무라나열매추출물', '브이피/다이메티코닐아크릴레이트/폴리카바밀/폴리글라이콜에스터', '키크노체스 쿠페리꽃/잎추출물', '치자적색소', '페녹시에틸파라벤', '로베지', '샘파이어캘러스배양추출물', '니파야자꽃봉오리추출물', '스냅진저꽃/잎/씨/줄기추출물', '체리모야추출물', '철피석곡추출물', '푸사누스 스피카투스목부추출물', '철피석곡캘러스', '라티폴리아라벤더추출물', '플랜틴즙', '디오스제닌다이펩타이드-33에이치씨엘', '치자황색소', '스피아민트허브오일', '아이소데실파라벤', '에스-왕귀뚜라미올리고펩타이드-1K아마이드', '겐티아나뿌리줄기/뿌리', '통가콩씨추출물', '사우수레아인볼루크라타추출물', '자주천인국잎/줄기분열조직세포배양추출물', '콜레칼시페놀피이지-12에터', '키투르스 타무라나꽃추출물', '페닐머큐릭아세테이트', '양박하꽃/잎/줄기추출물', '순코칸시트러스열매추출물', '샘파이어캘러스배양여과추출물', '플랜틴', '수어숍열매추출물', '디오스제닌
# ...
